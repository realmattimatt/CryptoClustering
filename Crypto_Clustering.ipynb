# %%
# Import required libraries and dependencies
import pandas as pd
import hvplot.pandas
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
# Out:
# <script type="esms-options">{"shimMode": true}</script><style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='dc1ae529-5881-44d5-a3b9-d43386b6cc5e'>
#   <div id="c5ec5bdd-0340-409e-b539-32bfde6981c8" data-root-id="dc1ae529-5881-44d5-a3b9-d43386b6cc5e" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
# Load the data into a Pandas DataFrame
df_market_data = pd.read_csv(
    "Resources/crypto_market_data.csv",
    index_col="coin_id")

# Display sample data
df_market_data.head(10)
# Out:
#                  price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                              1.08388                     7.60278
# ethereum                             0.22392                    10.38134
# tether                              -0.21173                     0.04935
# ripple                              -0.37819                    -0.60926
# bitcoin-cash                         2.90585                    17.09717
# binancecoin                          2.10423                    12.85511
# chainlink                           -0.23935                    20.69459
# cardano                              0.00322                    13.99302
# litecoin                            -0.06341                     6.60221
# bitcoin-cash-sv                      0.92530                     3.29641
#
#                  price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# ...

# %%
# Generate summary statistics
df_market_data.describe()
# Out:
#        price_change_percentage_24h  price_change_percentage_7d  \
# count                    41.000000                   41.000000
# mean                     -0.269686                    4.497147
# std                       2.694793                    6.375218
# min                     -13.527860                   -6.094560
# 25%                      -0.608970                    0.047260
# 50%                      -0.063410                    3.296410
# 75%                       0.612090                    7.602780
# max                       4.840330                   20.694590
#
#        price_change_percentage_14d  price_change_percentage_30d  \
# count                    41.000000                    41.000000
# mean                      0.185787                     1.545693
# std                       8.376939                    26.344218
# min                     -18.158900                   -34.705480
# 25%                      -5.026620                   -10.438470
# ...

# %%
# Plot your data to see what's in your DataFrame
df_market_data.hvplot.line(
    width=800,
    height=400,
    rot=90
)
# Out:
# :NdOverlay   [Variable]
#    :Curve   [coin_id]   (value)

# %% [markdown]
# ---

# %% [markdown]
# ### Prepare the Data

# %%
# Use the `StandardScaler()` module from scikit-learn to normalize the data from the CSV file
market_data_scaled = StandardScaler().fit_transform(df_market_data[["price_change_percentage_24h", "price_change_percentage_7d", "price_change_percentage_14d", "price_change_percentage_30d", "price_change_percentage_60d", "price_change_percentage_200d", "price_change_percentage_1y"]])

# %%
# Create a DataFrame with the scaled data
df_market_scaled = pd.DataFrame(
    market_data_scaled,
    columns=["price_change_percentage_24h", "price_change_percentage_7d", "price_change_percentage_14d", "price_change_percentage_30d", "price_change_percentage_60d", "price_change_percentage_200d", "price_change_percentage_1y"],
    
    # Set the coin_id column as index
    # Copy the crypto names from the original DataFrame
    index=df_market_data.index
)

# Display the scaled DataFrame
df_market_scaled.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Original Scaled DataFrame.

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
for k_value in range(1, 12):
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
    model = KMeans(n_clusters=k_value, random_state=42)
# 2. Fit the model to the data using `df_market_data_scaled`
    model.fit(df_market_scaled)
# 3. Append the model.inertia_ to the inertia list
    inertia.append(model.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {"k":k, "inertia":inertia} 

# Create a DataFrame with the data to plot the Elbow curve
df_elbow =  pd.DataFrame(elbow_data)

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
k_elbow_plot = df_elbow.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow Curve",
    xticks=k
)
k_elbow_plot
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the best value for `k`?
#
# **Answer:** 4

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Original Scaled DataFrame

# %%
# Initialize the K-Means model using the best value for k
k_model = KMeans(n_clusters=4, random_state=42)

# %%
# Fit the K-Means model using the scaled DataFrame
k_model.fit(df_market_scaled)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled DataFrame
predictions = k_model.predict(df_market_scaled)

# Print the resulting array of cluster values.
predictions
# Out:
# array([0, 0, 2, 2, 0, 0, 0, 0, 0, 2, 2, 2, 2, 0, 2, 0, 2, 2, 0, 2, 2, 0,
#        2, 2, 2, 2, 2, 2, 0, 2, 2, 2, 3, 0, 2, 2, 1, 2, 2, 2, 2],
#       dtype=int32)

# %%
# Create a copy of the scaled DataFrame
df_market_scaled_predictions = df_market_scaled.copy()

# %%
# Add a new column to the copy of the scaled DataFrame with the predicted clusters
df_market_scaled_predictions["predicted clusters"] = predictions

# Display the copy of the scaled DataFrame
df_market_scaled_predictions.head()
# Out:
#               price_change_percentage_24h  price_change_percentage_7d  \
# coin_id
# bitcoin                          0.508529                    0.493193
# ethereum                         0.185446                    0.934445
# tether                           0.021774                   -0.706337
# ripple                          -0.040764                   -0.810928
# bitcoin-cash                     1.193036                    2.000959
#
#               price_change_percentage_14d  price_change_percentage_30d  \
# coin_id
# bitcoin                          0.772200                     0.235460
# ethereum                         0.558692                    -0.054341
# tether                          -0.021680                    -0.061030
# ripple                           0.249458                    -0.050388
# bitcoin-cash                     1.760610                     0.545842
#
#               price_change_percentage_60d  price_change_percentage_200d  \
# coin_id
# ...

# %%
# Create a scatter plot using hvPlot by setting
# `x="price_change_percentage_24h"` and `y="price_change_percentage_7d"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
df_market_scaled_predictions_plot = df_market_scaled_predictions.hvplot.scatter(
    x="price_change_percentage_24h",
    y="price_change_percentage_7d",
    by="predicted clusters",
    hover_cols=["coin_id"]
)
df_market_scaled_predictions_plot
# Out:
# :NdOverlay   [predicted clusters]
#    :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)

# %% [markdown]
# ---

# %% [markdown]
# ### Optimize Clusters with Principal Component Analysis.

# %%
# Create a PCA model instance and set `n_components=3`.
pca = PCA(n_components=3)

# %%
# Use the PCA model with `fit_transform` to reduce the original scaled DataFrame
# down to three principal components.
pca_data = pca.fit_transform(df_market_scaled_predictions)

# View the scaled PCA data
pca_df = pd.DataFrame(
    pca_data,
    columns=["PCA1", "PCA2", "PCA3"]
)
pca_df.head()
# Out:
#        PCA1      PCA2      PCA3
# 0  1.585139  0.134394  0.545621
# 1  1.322581  0.054494  1.115709
# 2 -0.266335 -0.536409 -0.796946
# 3 -0.257225 -0.592013 -0.646529
# 4  2.952250  0.422372  1.267894

# %%
# Retrieve the explained variance to determine how much information
# can be attributed to each principal component.
explained_variance = pca.explained_variance_ratio_
explained_variance
# Out:
# array([0.37005408, 0.32322221, 0.19115222])

# %% [markdown]
# #### Answer the following question:
#
# **Question:** What is the total explained variance of the three principal components?
#
# **Answer:**   88

# %%
# Create a new DataFrame with the PCA data.
df_market_data_pca = pca_df.copy()
# Copy the crypto names from the original scaled DataFrame
df_market_data_pca = pd.DataFrame(
    pca_data, 
    columns=["PCA1", "PCA2", "PCA3"], 
    # Set the coin_id column as index
    index=df_market_scaled_predictions.index  # Ensure index is copied
)

# Display the scaled PCA DataFrame
df_market_data_pca.head()
# Out:
#                   PCA1      PCA2      PCA3
# coin_id
# bitcoin       1.585139  0.134394  0.545621
# ethereum      1.322581  0.054494  1.115709
# tether       -0.266335 -0.536409 -0.796946
# ripple       -0.257225 -0.592013 -0.646529
# bitcoin-cash  2.952250  0.422372  1.267894

# %% [markdown]
# ---

# %% [markdown]
# ### Find the Best Value for k Using the Scaled PCA DataFrame

# %%
# Create a list with the number of k-values from 1 to 11
k = list(range(1, 12))

# %%
# Create an empty list to store the inertia values
inertia = []

# Create a for loop to compute the inertia with each possible value of k
for k_value in range(1, 12):
# Inside the loop:
# 1. Create a KMeans model using the loop counter for the n_clusters
    model = KMeans(n_clusters=k_value, random_state=42)
# 2. Fit the model to the data using `df_market_data_pca`
    model.fit(df_market_data_pca)
# 3. Append the model.inertia_ to the inertia list
    inertia.append(model.inertia_)

# %%
# Create a dictionary with the data to plot the Elbow curve
elbow_data = {"k":k, "inertia":inertia} 
# Create a DataFrame with the data to plot the Elbow curve
df_elbow =  pd.DataFrame(elbow_data)

# %%
# Plot a line chart with all the inertia values computed with
# the different values of k to visually identify the optimal value for k.
pca_elbow_plot = df_elbow.hvplot.line(
    x="k",
    y="inertia",
    title="Elbow Curve",
    xticks=k
)
pca_elbow_plot
# Out:
# :Curve   [k]   (inertia)

# %% [markdown]
# #### Answer the following questions:
#
# * **Question:** What is the best value for `k` when using the PCA data?
#
#   * **Answer:** 4
#
#
# * **Question:** Does it differ from the best k value found using the original data?
#
#   * **Answer:** No

# %% [markdown]
# ### Cluster Cryptocurrencies with K-means Using the Scaled PCA DataFrame

# %%
# Initialize the K-Means model using the best value for k
model = KMeans(n_clusters=4, random_state=42)

# %%
# Fit the K-Means model using the PCA data
model.fit(df_market_data_pca)
# Out:
# KMeans(n_clusters=4, random_state=42)

# %%
# Predict the clusters to group the cryptocurrencies using the scaled PCA DataFrame
cluster_labels = model.predict(df_market_data_pca)

# Print the resulting array of cluster values.
print(df_market_data_pca)
# Out:
#                           PCA1      PCA2      PCA3
# coin_id
# bitcoin               1.585139  0.134394  0.545621
# ethereum              1.322581  0.054494  1.115709
# tether               -0.266335 -0.536409 -0.796946
# ripple               -0.257225 -0.592013 -0.646529
# bitcoin-cash          2.952250  0.422372  1.267894
# binancecoin           1.975484  0.528219  0.670145
# chainlink             1.671906  0.178423  2.718598
# cardano               1.539740  0.324517  1.497226
# litecoin              1.347533 -0.132837  0.791063
# bitcoin-cash-sv      -0.040698 -0.802083 -0.465562
# crypto-com-chain     -1.344822 -1.108679 -1.076912
# usd-coin             -0.272121 -0.545849 -0.814012
# eos                  -0.320673 -0.918019 -0.637918
# monero                2.838740  1.895142  0.848863
# tron                 -0.143758 -0.442297 -0.274682
# tezos                 0.862155 -0.757488  1.490647
# okb                  -1.378653 -0.776673 -0.754383
# ...

# %%
# Create a copy of the scaled PCA DataFrame
df_market_data_pca_scaled = df_market_data_pca.copy()

# Add a new column to the copy of the PCA DataFrame with the predicted clusters
df_market_data_pca_scaled["Cluster"] = cluster_labels

# Display the copy of the scaled PCA DataFrame
df_market_data_pca_scaled.head()
# Out:
#                   PCA1      PCA2      PCA3  Cluster
# coin_id
# bitcoin       1.585139  0.134394  0.545621        0
# ethereum      1.322581  0.054494  1.115709        0
# tether       -0.266335 -0.536409 -0.796946        1
# ripple       -0.257225 -0.592013 -0.646529        1
# bitcoin-cash  2.952250  0.422372  1.267894        0

# %%
# Create a scatter plot using hvPlot by setting
# `x="PC1"` and `y="PC2"`.
# Color the graph points with the labels found using K-Means and
# add the crypto name in the `hover_cols` parameter to identify
# the cryptocurrency represented by each data point.
df_market_data_pca_scaled_plot= df_market_data_pca_scaled.hvplot.scatter(
    x="PCA1",
    y="PCA2",
    by="Cluster",
    hover_cols=["coin_id"],
    size=100,
    title="Cryptocurrency Clusters"
)
df_market_data_pca_scaled_plot
# Out:
# :NdOverlay   [Cluster]
#    :Scatter   [PCA1]   (PCA2,coin_id)

# %% [markdown]
# ### Visualize and Compare the Results
#
# In this section, you will visually analyze the cluster analysis results by contrasting the outcome with and without using the optimization techniques.

# %%
# Composite plot to contrast the Elbow curves
k_elbow_plot = k_elbow_plot.relabel("Elbow Curve - K-Means")
pca_elbow_plot = pca_elbow_plot.relabel("Elbow Curve - PCA Optimized")

# Combine plots
(k_elbow_plot * pca_elbow_plot).opts(legend_position="top_right")
# Out:
# :Overlay
#    .Curve.Elbow_Curve_hyphen_minus_K_hyphen_minus_Means :Curve   [k]   (inertia)
#    .Curve.Elbow_Curve_hyphen_minus_PCA_Optimized        :Curve   [k]   (inertia)

# %%
(k_elbow_plot + pca_elbow_plot).opts(legend_position="top_right")
# Out:
# :Layout
#    .Curve.Elbow_Curve_hyphen_minus_K_hyphen_minus_Means :Curve   [k]   (inertia)
#    .Curve.Elbow_Curve_hyphen_minus_PCA_Optimized        :Curve   [k]   (inertia)

# %%
# Composite plot to contrast the clusters
(df_market_scaled_predictions_plot + df_market_data_pca_scaled_plot).cols(1)
# Out:
# :Layout
#    .NdOverlay.I  :NdOverlay   [predicted clusters]
#       :Scatter   [price_change_percentage_24h]   (price_change_percentage_7d,coin_id)
#    .NdOverlay.II :NdOverlay   [Cluster]
#       :Scatter   [PCA1]   (PCA2,coin_id)

# %% [markdown]
# #### Answer the following question:
#
#   * **Question:** After visually analyzing the cluster analysis results, what is the impact of using fewer features to cluster the data using K-Means?
#
#   * **Answer:**
#   * The PCA shows a much greater trend to show associations clustered much tighter. In some instances, reducing the dimensions will get rid of a lot of clutter.
